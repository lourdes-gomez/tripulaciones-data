# %%
from bs4 import BeautifulSoup as bs
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import lxml

import time
import pandas as pd

# %%
driver = webdriver.Chrome()

url = "https://web.whatsapp.com/"

driver.get(url)

# %%
# soup = bs(driver.page_source,"lxml")

soup = bs(driver.page_source, "html.parser")

# %%
soup
# Out:
# <html class="js serviceworker adownload cssanimations csstransitions webp exiforientation webp-alpha webp-animation webp-lossless wf-loading" dir="LTR" lang="es" loc="es"><head><meta charset="utf-8"/><meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/><title>WhatsApp</title><meta content="width=device-width" name="viewport"/><meta content="notranslate" name="google"/><meta content="telephone=no" name="format-detection"/><meta content="Envía y recibe rápidamente mensajes de WhatsApp desde tu computadora." name="description"/><meta content="Envía y recibe rápidamente mensajes de WhatsApp desde tu computadora." name="og:description"/><meta content="https://web.whatsapp.com/" name="og:url"/><meta content="WhatsApp Web" name="og:title"/><meta content="https://static.facebook.com/images/whatsapp/www/whatsapp-promo.png" name="og:image"/><link href="/apple-touch-icon.png" rel="apple-touch-icon" sizes="192x192" type="image/png"/><meta content="#111b21" media="(prefers-color-scheme:
# ...

# %%
contactos = soup.select('div.Mk0Bp._30scZ')
contactos
# Out:
# [<div class="Mk0Bp _30scZ"><span aria-label="" class="l7jjieqr _11JPr" dir="auto" style="min-height: 0px;">Zamo</span></div>,
#  <div class="Mk0Bp _30scZ"><span aria-label="Quizá Joan" class="l7jjieqr _11JPr" dir="auto" style="min-height: 0px;">~ Joan</span></div>,
#  <div class="Mk0Bp _30scZ"><span aria-label="" class="l7jjieqr _11JPr" dir="auto" style="min-height: 0px;">Feli Bootcamp</span></div>,
#  <div class="Mk0Bp _30scZ"><span aria-label="" class="l7jjieqr _11JPr" dir="auto" style="min-height: 0px;">Tú</span></div>,
#  <div class="Mk0Bp _30scZ"><span aria-label="" class="ggj6brxn gfz4du6o r7fjleex g0rxnol2 lhj4utae le5p0ye3 l7jjieqr _11JPr" dir="auto" style="min-height: 0px;" title="Álex Bootcamp">Álex Bootcamp</span></div>,
#  <div class="Mk0Bp _30scZ"><span aria-label="" class="l7jjieqr _11JPr" dir="auto" style="min-height: 0px;">Lucía</span></div>,
#  <div class="Mk0Bp _30scZ"><span aria-label="" class="l7jjieqr _11JPr" dir="auto" style="min-height: 0px;">Tjr</span></div>,
# ...

# %%
contactos = soup.select('div.Mk0Bp._30scZ span')
lista_contactos = []
for contacto in contactos:
    lista_contactos.append(contacto.get_text())
lista_contactos
# Out:
# ['Zamo',
#  '~\u202fJoan',
#  'Feli Bootcamp',
#  'Tú',
#  'Álex Bootcamp',
#  'Lucía',
#  'Tjr',
#  '~\u202fAndres',
#  'Tú',
#  'Dani Bootcamp',
#  'Tú',
#  'Manu',
#  'Eli Bootcamp',
#  'Mamá New',
#  'Lucía',
#  'Lucas Arg',
#  '~\u202fpabl_vlone']

# %% [markdown]
# Soup de solo el último chat

# %%
from bs4 import BeautifulSoup as bs
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import lxml

import time
import pandas as pd

# %%
driver = webdriver.Chrome()

url = "https://web.whatsapp.com/"

driver.get(url)

# %%
browse = driver.find_element(By.XPATH, '/html/body/gg-app/div/gg-header/header/nav/div/div[1]/div/div[1]/ul/li[1]/button')
browse.click()

# %%
soup = bs(driver.page_source, "html.parser")

# %%
soup

# %%
mensajes = soup.select('div.Mk0Bp._30scZ span')
lista_mensajes = []
for mensaje in mensajes:
    lista_mensajes.append(mensaje.get_text())
lista_mensajes
